# %% [markdown]
# # CS4035 - Cyber Data Analytics
# ## Lab 2 LOF - ARMA
# ### Group 33 - Martijn van Meerten 4387902

# %%
# If this cell does not work try running `pip install nbformat`

import io
from IPython import nbformat

nb = nbformat.read("lab2_LOF_ARMA.ipynb", nbformat.NO_CONVERT)
word_count = 0
for cell in nb.cells:
    if cell.cell_type == "markdown":
        word_count += len(cell['source'].replace('#', '').lstrip().split(' '))

print("Word count:", word_count)
# Out:
# Word count: 30

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from sklearn.neighbors import LocalOutlierFactor

# %% [markdown]
# ## Pre-processing

# %%
df = pd.read_csv('SWaT_train.csv', skipinitialspace=True)
df.drop(columns=["Timestamp", "Normal/Attack"], inplace=True)
df = df[30000:]
X = df.to_numpy()

# %%
df_test = pd.read_csv('SWaT_test.csv')
df_test.loc[df_test['Normal/Attack'] == 'Attack', 'Normal/Attack'] = 1 # Attack
df_test.loc[df_test['Normal/Attack'] == 'Normal', 'Normal/Attack'] = 0 # Normal
y = df_test['Normal/Attack'].to_numpy().astype(int)
df_test.drop(columns=["Unnamed: 0", " Timestamp", "Normal/Attack"], inplace=True)

# %%
print(y)
# Out:
# [0 0 0 ... 0 0 0]

# %% [markdown]
# ## 2. LOF task – 1/2 A4 – Individual

# %% [markdown]
# ### 2a. Plot LOF scores

# %% [markdown]
# Plot LOF scores over time series

# %%
np.random.seed(42)

# Sample 50000 rows from the training data
#X_50000 = X[np.random.choice(X.shape[0], 50000, replace=False), :]
X_50000 = X[50000:100000]
negative_outlier_factors = []

for n_neighbors in range(15, 45, 5):
    clf = LocalOutlierFactor(n_neighbors=n_neighbors)
    y_pred = clf.fit_predict(X_50000)
    negative_outlier_factors.append(clf.negative_outlier_factor_ * -1)

# %%
fig, ax = plt.subplots(len(negative_outlier_factors))
fig.set_figheight(16)
fig.set_figwidth(13)

def label(k):
    return '{} neighbors'.format(k)

for i in range(len(negative_outlier_factors)):
    ax[i].plot(range(30000, 35000), negative_outlier_factors[i][30000:35000], label=label(range(15, 50, 5)[i]), color='blue')
    ax[i].set_xlabel('Time')
    ax[i].set_ylabel('LOF score', color='blue')
    ax[i].legend()
    ax2 = ax[i].twinx()
    ax2.plot(range(30000, 35000), df)
    ax2.set_ylabel('Value', color='red')

#ax.set_title("")
#ax.set_xlabel("Time (s)")
#ax.set_ylabel("Value")
#ax.legend(loc="lower right")

# %% [markdown]
# ### 2b. Analysis and answers to the questions

# %% [markdown]
# 3.
# 4. LOF is suited for point-based anomaly detection. It is able detect a row with an unusual combination of features. It is not suited for contextual anomaly detection or collective anomly detection.

# %% [markdown]
# ## 4. ARMA task – 1/2 A4 - Individual

# %% [markdown]
# ### 4a. Print relevant plots and/or metrics to determine the parameters.

# %% [markdown]
# We plot the ACF and PACF plots for five different signals. From these plots we will determine the orders of the ARMA models.

# %%
### WARNING: Running this cell takes roughly 10 minutes ###
fig, ax = plt.subplots(5, 2)
fig.set_figheight(16)
fig.set_figwidth(16)

# Plot the ACF and PACF plots for five different signals
plot_acf(df['LIT101'], ax=ax[0][0], title="ACF LIT101");
plot_acf(df['MV301'], ax=ax[1][0], title="ACF MV301");
plot_acf(df['P203'], ax=ax[2][0], title="ACF P203");
plot_acf(df['AIT203'], ax=ax[3][0], title="ACF AIT203");
plot_acf(df['DPIT301'], ax=ax[4][0], title="ACF DPIT301");
plot_pacf(df['LIT101'], ax=ax[0][1], title="PACF LIT101");
plot_pacf(df['MV301'], ax=ax[1][1], title="PACF MV301");
plot_pacf(df['P203'], ax=ax[2][1], title="PACF P203");
plot_pacf(df['AIT203'], ax=ax[3][1], title="PACF AIT203");
plot_pacf(df['DPIT301'], ax=ax[4][1], title="PACF DPIT301");

# %% [markdown]
# A slowly decreasing or constant **ACF** and a sudden cut-off for **PACF** indicate an **AR** model, where the order is determined by the lag at which the cut-off happens. LIT101, P203, AIT203 and DPIT301 exhibit this behavior. Therefore,
# - LIT101: AR(4)
# - MV301: AR(2)
# - P203: AR(2)
# - AIT203: AR(2)
# - DPIT301: AR(3)
#
# A slowly decreasing or constant **PACF** and a sudden cut-off for **ACF** indicate a **MA** model, where the order is once again determined by the lag which the cut-off happens. xxx, xxx exhibit this behavior. Therefore,
# - xxx: xxx
#
# If both **PACF** and **ACF** slowly decrease, most likely an **ARMA(1, 1)** model best fits the time series. xxx exhibits this behavior. Therefore,
# - MV301: ARMA(2, 35)??

# %%
# Train models
LIT101 = ARIMA(df['LIT101'], order=(4, 0, 0)).fit()
print('LIT101 AR(4) = {}'.format(LIT101.aic))
P203 = ARIMA(df['P203'], order=(2, 0, 0)).fit()
print('P203 AR(2) = {}'.format(P203.aic))
AIT203 = ARIMA(df['AIT203'], order=(2, 0, 0)).fit()
print('AIT203 AR(2) = {}'.format(AIT203.aic))
DPIT301 = ARIMA(df['DPIT301'], order=(3, 0, 0)).fit()
print('DPIT301 AR(3) = {}'.format(LIT101.aic))
MV301 = ARIMA(df['MV301'], order=(2, 0, 0)).fit()
print('MV301 AR(2) = {}'.format(MV301.aic))
MV301 = ARIMA(df['MV301'], order=(2, 0, 1)).fit()
print('MV301 ARMA(2, 1) = {}'.format(MV301.aic))
# Out:
# LIT101 AR(4) = 223549.42728576326
# P203 AR(2) = -2222474.7427533874
# AIT203 AR(2) = -1112030.0349620257
# DPIT301 AR(3) = 223549.42728576326
# MV301 AR(2) = -1493645.239555052
# c:\users\martijn.vanmeerten\appdata\local\programs\python\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\users\martijn.vanmeerten\appdata\local\programs\python\python39\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# MV301 ARMA(2, 1) = -1492712.9738381014

# %%
result.resid
# Out:
# 30000    -92.742518
# 30001      0.352674
# 30002      0.095717
# 30003      0.023802
# 30004     -0.591599
#             ...
# 496795    -0.274969
# 496796    -0.212198
# 496797    -0.107542
# 496798     0.099445
# 496799    -0.059846
# Length: 466800, dtype: float64

# %%
LIT101_test = LIT101.apply(df_test['LIT101'])
P203_test = P203.apply(df_test['P203'])
AIT203_test = AIT203.apply(df_test['AIT203'])
DPIT301_test = DPIT301.apply(df_test['DPIT301'])
MV301_test = MV301.apply(df_test['MV301'])

# %%
normal_points = LIT101_test.resid[y==0][130000:200000]
plt.plot(normal_points)

# %%
def plot_residuals(training_results, test_results, y, title='Residuals of signal'):
    fig, ax = plt.subplots(1, 2)
    fig.set_figwidth(16)
    fig.suptitle(title)
    ax[0].plot(training_results.resid[1:])
    ax[0].set_xlabel('Time')
    ax[0].set_ylabel('Residual error')
    ax[0].set_title('Training data')
    ax[1].plot(test_results.resid[1:], color='blue', label='Residuals')
    ax[1].plot(test_results.resid[y==1], 'ro', label='Attack')
    ax[1].set_xlabel('Time')
    ax[1].set_ylabel('Residual error')
    ax[1].legend()
    ax[1].set_title('Test data')

def print_performance_stats(threshold, test_results, y, signal_name):
    print('Number of attack points: {}'.format((y == 1).sum()))
    print('Number of detections: {}'.format((test_results.resid > threshold).sum() + (test_results.resid < -threshold).sum()))
    print('Number of true positives: {}'.format((test_results.resid[y==1] > threshold).sum() + (test_results.resid[y==1] < -threshold).sum()))
    print('Number of false positives: {}'.format((test_results.resid[y==0] > threshold).sum() + (test_results.resid[y==0] < -threshold).sum()))

plot_residuals(LIT101, LIT101_test, y, 'LIT101')
#print_performance_stats(4, LIT101_test, y, 'LIT101')
plot_residuals(AIT203, AIT203_test, y, 'AIT203')
#print_performance_stats(4, AIT203_test, y, 'P203')
plot_residuals(P203, P203_test, y, 'P203')
plot_residuals(DPIT301, DPIT301_test, y, 'DPIT301')
plot_residuals(MV301, MV301_test, y, 'MV301')

# %%
P203_test = P203.extend(df_test['P203'])
AIT203_test = AIT203.extend(df_test['AIT203'])
DPIT301_test = DPIT301.extend(df_test['DPIT301'])
MV301_test = MV301.extend(df_test['MV301'])

# %%
prediction = result.predict()
fig, ax = plt.subplots()
ax.plot(range(80000, 87000), prediction[80000:87000], label='prediction', color='red')
ax.plot(range(80000, 86000), df['LIT101'][80000:86000], label='training', color='blue')
ax.plot(range(80000, 86000), df['LIT101'][80000:86000] - prediction[80000:86000], label='error', color='green')
ax.set_xlabel('Time')
ax.set_ylabel('value')
ax.legend()
print(prediction)
print(df['LIT101'])
# Out:
# 30000     593.254418
# 30001     500.512526
# 30002     501.083483
# 30003     501.430198
# 30004     501.692299
#              ...
# 496795    523.317969
# 496796    523.176698
# 496797    522.993542
# 496798    522.825755
# 496799    522.906546
# Name: predicted_mean, Length: 466800, dtype: float64
# 30000     500.5119
# 30001     500.8652
# 30002     501.1792
# 30003     501.4540
# 30004     501.1007
#             ...
# 496795    523.0430
# 496796    522.9645
# 496797    522.8860
# 496798    522.9252
# 496799    522.8467
# Name: LIT101, Length: 466800, dtype: float64

# %%
ARIMA(df['LIT101'], order=(3, 0, 0)).fit().aic
# Out:
# 231063.3996520364

# %%
ARIMA(df['LIT101'], order=(15, 0, 0)).fit().aic
# Out:
# 204828.1834848752

# %% [markdown]
# ### 4b. Plots to study the detected anomalies

# %% [markdown]
# ### 4c. Analysis and answers to the questions
